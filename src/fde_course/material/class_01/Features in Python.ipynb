# %% [markdown]
# ### Features in Python

# %% [markdown]
# 1. Python is Dynamically typed language
# 2. Easy to code and easy to read
# 3. Interpreted Language
# 4. Cross-Platform Compatibility:
#     Windows
#     Linux
#     MacOS
#
# 5. Open Source and Free
# 6. Extensive Standard Library:
#     import os
#     import re
#     import time
#     import flask
#     import pandas
#
# 7. Object Oriented Programming Language (OOPs):
#     High Level Programming/Functional Programming(Class,functions)
#     Structured code format
#
# 8. Support for Modules and Packages
#     Reusability
#     Module >> Single python file with (.py) extension
#     Packages >> Folder with multiple modules
#
# 9. Ease of Integration:
#     Database
#     Web Framework
#
# 10. It supports for Graphical User Interface(GUI)
#     streamlit
#     tkinter
#
# 11. Python is a case sensitive language

# %%
a = 45
id(a)
# Out:
# 140726909667624

# %%
abhishek = 15
Abhishek = 45
print(abhishek)
# Out:
# 15

# %%
Abhishek
# Out:
# 45

# %% [markdown]
# Age int
# gender CHAR

# %%
a = 9
type(a)
# Out:
# int

# %%
s = 'Text'
type(s)
# Out:
# str

# %%
import os
# import pandas

# %% [markdown]
# ![image.png](attachment:b502d8ec-f6dc-4cb5-a58f-68db097266c5.png)![image.png](attachment:297aafc6-5db3-4f35-a914-2c234ac88c2c.png)

# %%
int, float, complex
str
list, tuple, set, frozenset, dict
None, bytes, bytearray

# %%
x = 15
type(x)
# Out:
# int

# %%
x2 = 15.1
type(x2)
# Out:
# float

# %%
x3 = '15.1'
type(x3)
# Out:
# str

# %%
x3 = 'Akshay'
type(x3)
# Out:
# str

# %%
x = 15
print(x)

y = 21
print(y)

add = x + y 
print(add)
# Out:
# 15
# 21
# 36

# %%
x = 15
print(x)

y = 21
print(y)

add = x + z
print(add)
# Out:
# 15
# 21
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4 y = 21
#       5 print(y)
# ----> 7 add = x + z
#       8 print(add)
#
# NameError: name 'z' is not defined

# %%
x = 15
print(x)

y = 21
print(y)

add = x + z
print(add)

add2= x + y
print(Add2)
# Out:
# 15
# 21
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       4 y = 21
#       5 print(y)
# ----> 7 add = x + z
#       8 print(add)
#      10 add2= x + y
#
# NameError: name 'z' is not defined

# %% [markdown]
# x = 15
# print(x)
#
# y = 21
# print(y)
#
# add = x + z
# print(add)
#
# add2= x + y
#  print(add2)

# %% [markdown]
# x = 15
# print(x)
#
# y = 21
# print(y)
#
# add = x + z
# print(add)
#
# add2= x + y)
# print(add2)

# %%
x = 15
print(x)

y = 21
print(y)

add = x + y
print(add)

add2= x + z
print(add2)
# Out:
# 15
# 21
# 36
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 10
#       7 add = x + y
#       8 print(add)
# ---> 10 add2= x + z
#      11 print(add2)
#
# NameError: name 'z' is not defined
