# %% [markdown]
# ### String Functions

# %%
1. Strings are enclosed by qoutes '' , "", ''''''
2. String are Immutable (We cannot modify or change existing string)
3. Strings are not comma,space separated

# %%
str1 = 'Data Science'
str1
# Out:
# 'Data Science'

# %% [markdown]
# ### Strings Functions

# %%
1. capitalize()
2. upper()
3. lower()
4. title()
5. swapcase()

6. lstrip()
7. rstrip() 
8. strip()
9. replace()

10. count()
11. index()
12. find()
13. rindex()
14. rfind()

15. split() # ans in list
16. join()  # ans in str

17. endswith()
18. startswith()

19. isalpha()
20. isalnum()
21. isdecimal()
22. isdigit()
23. isnumeric()

24. islower()
25. isupper()
26. istitle()
27. isspace()

28. zfill()
29. center()

# %% [markdown]
# ### 1. Capitalize

# %%
It will capitalize only first character of string and all remaining characters will be in lower case

# %%
str1 = 'Data Science'
str1.capitalize()
# Out:
# 'Data science'

# %%
str1
# Out:
# 'Data Science'

# %%
str1 = 'data science'
str1.capitalize()
# Out:
# 'Data science'

# %%
str1
# Out:
# 'data science'

# %%
str1 = 'DATA SCIENCE'
str1.capitalize()
# Out:
# 'Data science'

# %%
str1 = 'DATA SCIENCE'
str2 = str1.capitalize()
str2
# Out:
# 'Data science'

# %%
str1
# Out:
# 'DATA SCIENCE'

# %%
str1 = 'DATA SCIENCE'
str1 = str1.capitalize()
str1
# Out:
# 'Data science'

# %% [markdown]
# ### 2. upper

# %%
It will convert all char into upper case

# %%
str1 = 'data science'
str1.upper()
# Out:
# 'DATA SCIENCE'

# %%
str1 = 'Data SCIENCE'
str1.upper()
# Out:
# 'DATA SCIENCE'

# %%
str1
# Out:
# 'Data SCIENCE'

# %% [markdown]
# ### 3. lower

# %%
It will convert all char into lower case

# %%
str1 = 'Data SCIENCE'
str1.lower()
# Out:
# 'data science'

# %%
str1 = '''Data science is a multidisciplinary field that uses scientific methods, algorithms,
and processes to extract knowledge and insights from data. It combines principles from mathematics,
statistics, computer science, and domain expertise to analyze data, solve problems, and make predictions. '''
str1.lower()
# Out:
# 'data science is a multidisciplinary field that uses scientific methods, algorithms,\nand processes to extract knowledge and insights from data. it combines principles from mathematics,\nstatistics, computer science, and domain expertise to analyze data, solve problems, and make predictions. '

# %%
str1 = '''Data science is a multidisciplinary field that uses scientific methods, algorithms,
and processes to extract knowledge and insights from data. It combines principles from mathematics,
statistics, computer science, and domain expertise to analyze data, solve problems, and make predictions. '''
str2 = str1.lower()
print(str2)
# Out:
# data science is a multidisciplinary field that uses scientific methods, algorithms,
# and processes to extract knowledge and insights from data. it combines principles from mathematics,
# statistics, computer science, and domain expertise to analyze data, solve problems, and make predictions.

# %% [markdown]
# ### 4. title

# %%
First character of every word will be in upper case and all remaining character will be in lower case

# %%
str1 = 'python and data science'
str1.title()
# Out:
# 'Python And Data Science'

# %%
str1 = 'python and DATA science'
str1.title()
# Out:
# 'Python And Data Science'

# %%
str1 = 'united states of america'
str1.title()
# Out:
# 'United States Of America'

# %%
str2 = '''Data science is a multidisciplinary field that combines statistical methods, 
machine learning, and computational techniques to extract meaningful insights and make predictions from data.'''

str2.title()
# Out:
# 'Data Science Is A Multidisciplinary Field That Combines Statistical Methods, \nMachine Learning, And Computational Techniques To Extract Meaningful Insights And Make Predictions From Data.'

# %%
str2
# Out:
# 'Data science is a multidisciplinary field that combines statistical methods, \nmachine learning, and computational techniques to extract meaningful insights and make predictions from data.'

# %%
str2 = '''Data science is a multidisciplinary field that combines statistical methods, 
machine learning, and computational techniques to extract meaningful insights and make predictions from data.'''

str3 = str2.title()
print(str3)
# Out:
# Data Science Is A Multidisciplinary Field That Combines Statistical Methods,
# Machine Learning, And Computational Techniques To Extract Meaningful Insights And Make Predictions From Data.

# %%
name = 'rohit sharma'
name.title()
# Out:
# 'Rohit Sharma'

# %%
adhar_name = 'Rohit Sharma'
pan_name = 'ROHIT SHARMA'

adhar_name == pan_name
# Out:
# False

# %%
adhar_name = 'Rohit Sharma'
pan_name = 'ROHIT SHARMA'

print('Adhar Name:', adhar_name.title())
print('PAN Name:', pan_name.title())

adhar_name.title() == pan_name.title()
# Out:
# Adhar Name: Rohit Sharma
# PAN Name: Rohit Sharma
# True

# %%
adhar_name = 'Rohit Sharma'
pan_name = 'ROHIT SHARMA'

print('Adhar Name:', adhar_name.lower())
print('PAN Name:', pan_name.lower())

adhar_name.lower() == pan_name.lower()
# Out:
# Adhar Name: rohit sharma
# PAN Name: rohit sharma
# True

# %% [markdown]
# ### 5. swapcase

# %%
Inverts the case of the case

# %%
adhar_name = 'Rohit Sharma'
adhar_name.swapcase()
# Out:
# 'rOHIT sHARMA'

# %%
pan_name = 'ROHIT SHARMA'
pan_name.swapcase()
# Out:
# 'rohit sharma'

# %% [markdown]
# ### 6. lstrip

# %%
OCR >> Optical Character Recognition (Image >> extract >> Text)

lstrip >> it removes all leadning white spaces from string

# %%
str1 = '     Government of India'
str1.lstrip()
# Out:
# 'Government of India'

# %%
str1 = '     Government of India'
len(str1)
# Out:
# 24

# %%
str1 = '     Government of India'
len(str1.lstrip())
# Out:
# 19

# %%
s1 = ' data'
s2 = 'data'

s1==s2
# Out:
# False

# %%
s1 = ' data'
s2 = 'data '

s1==s2
# Out:
# False

# %% [markdown]
# ### 7. rstrip

# %%
rstrip >> it removes all trailing white spaces

# %%
s1 = 'data Science         '
s1.rstrip()
# Out:
# 'data Science'

# %%
s1 = 'data Science         '
s1.lstrip()
# Out:
# 'data Science         '

# %%
s1 = 'data Science                       a       '
s1.rstrip()
# Out:
# 'data Science                       a'

# %% [markdown]
# ### 8. strip

# %%
Remove white spaces from left and right side

# %%
s1 = '           data Science         '
type(s1.lstrip())
# Out:
# str

# %%
s1 = '           data Science         '
s1.lstrip().rstrip()
# Out:
# 'data Science'

# %%
s1 = '           data Science         '
s1.strip()
# Out:
# 'data Science'

# %%
s1 = '         Python           data              Science              '
s1.strip()
# Out:
# 'Python           data              Science'

# %% [markdown]
# ### 9. replace

# %%
str.replace(old_substring, new_substring)
substring >> part of original string

# %%
str1 = 'python and data science'
str1.replace('python','Java')
# Out:
# 'Java and data science'

# %%
str1
# Out:
# 'python and data science'

# %%
str1 = 'python and data science'
str2 = str1.replace('python','Java')

print(str1)
print(str2)
# Out:
# python and data science
# Java and data science

# %%
str1 = 'python and data science'
str2 = str1.replace('python','PYTHON')

print(str1)
print(str2)
# Out:
# python and data science
# PYTHON and data science

# %%
str1 = 'python and data science'
str2 = str1.replace('Machine Learning','Deep Learning')

print(str1)
print(str2)
# Out:
# python and data science
# python and data science

# %%
str1 = 'python and Machine Learning'
str2 = str1.replace('Machine Learning','AAAAAAAAAAAAAA')

print(str1)
print(str2)
# Out:
# python and Machine Learning
# python and AAAAAAAAAAAAAA

# %%
str1 = 'python and  Machine Learning'
str2 = str1.replace('  ','-')

print(str1)
print(str2)
# Out:
# python and  Machine Learning
# python and-Machine Learning

# %%
str1 = 'python and Deep Learning'
str2 = str1.replace('p','P')

print(str1)
print(str2)
# Out:
# python and Deep Learning
# Python and DeeP Learning

# %%
str1 = 'python and Deep Learning'
str2 = str1.title()

print(str1)
print(str2)
# Out:
# python and Deep Learning
# Python And Deep Learning

# %%
string = """Data science is an Interdisciplinary academic field[1] that Uses statistics, 
scientific computing, scientific methods, processing, Scientific visualIzation, 
algorithms and systems to Extract or Extrapolate knowledge from potentially noisy, 
structured, Or unstructured data."""

# %%
# Gopal
string.replace('a',' ').replace('e',' ').replace('i',' ').replace('o',' ').replace('u',' ')
# Out:
# 'D t  sc  nc   s  n Int rd sc pl n ry  c d m c f  ld[1] th t Us s st t st cs, \nsc  nt f c c mp t ng, sc  nt f c m th ds, pr c ss ng, Sc  nt f c v s  lIz t  n, \n lg r thms  nd syst ms t  Extr ct  r Extr p l t  kn wl dg  fr m p t nt  lly n  sy, \nstr ct r d, Or  nstr ct r d d t .'

# %%
# Bharat
string1 = string.replace("a",'')
string1 = string1.replace("e",'')
string1 = string1.replace("i",'')
string1 = string1.replace("o",'')
string1 = string1.replace("u",'')
print(string1)
# Out:
# Dt scnc s n Intrdscplnry cdmc fld[1] tht Uss sttstcs,
# scntfc cmptng, scntfc mthds, prcssng, Scntfc vslIztn,
# lgrthms nd systms t Extrct r Extrplt knwldg frm ptntlly nsy,
# strctrd, Or nstrctrd dt.

# %%
# Shivaji
string.replace('A',' ').replace('a',' ').replace('E',' ').replace('e',' ').replace('I',' ').replace('i',' ').replace('O',' ').replace('o',' ').replace('U',' ').replace('u',' ')
# Out:
# 'D t  sc  nc   s  n  nt rd sc pl n ry  c d m c f  ld[1] th t  s s st t st cs, \nsc  nt f c c mp t ng, sc  nt f c m th ds, pr c ss ng, Sc  nt f c v s  l z t  n, \n lg r thms  nd syst ms t   xtr ct  r  xtr p l t  kn wl dg  fr m p t nt  lly n  sy, \nstr ct r d,  r  nstr ct r d d t .'

# %%
# Anurag
string = string.lower()
print(string.replace('a', '').replace('e','').replace('o', '').replace('u', '').replace('i', ''))
# Out:
# dt scnc s n ntrdscplnry cdmc fld[1] tht ss sttstcs,
# scntfc cmptng, scntfc mthds, prcssng, scntfc vslztn,
# lgrthms nd systms t xtrct r xtrplt knwldg frm ptntlly nsy,
# strctrd, r nstrctrd dt.

# %%
print(string.lower().replace('a', '').replace('e','').replace('o', '').replace('u', '').replace('i', ''))
# Out:
# dt scnc s n ntrdscplnry cdmc fld[1] tht ss sttstcs,
# scntfc cmptng, scntfc mthds, prcssng, scntfc vslztn,
# lgrthms nd systms t xtrct r xtrplt knwldg frm ptntlly nsy,
# strctrd, r nstrctrd dt.

# %%
string = """Data science is an Interdisciplinary academic field[1] that Uses statistics, 
scientific computing, scientific methods, processing, Scientific visualIzation, 
algorithms and systems to Extract or Extrapolate knowledge from potentially noisy, 
structured, Or unstructured data."""

for i in 'aeiou':
    if i in string.lower():
        string = string.lower().replace(i, '')

print(string)
# Out:
# dt scnc s n ntrdscplnry cdmc fld[1] tht ss sttstcs,
# scntfc cmptng, scntfc mthds, prcssng, scntfc vslztn,
# lgrthms nd systms t xtrct r xtrplt knwldg frm ptntlly nsy,
# strctrd, r nstrctrd dt.

# %%
str2 = 'python 1234'
str2.replace('1234','')
# Out:
# 'python '

# %%
str2 = 'python and data science'
str2.replace(' ','--')
# Out:
# 'python--and--data--science'

# %%
str2 = 'python and data science'
str2.replace(' ', '  ')
# Out:
# 'python  and  data  science'

# %%
str2 = 'python and data science'
str2.replace(' ', '')
# Out:
# 'pythonanddatascience'

# %%
str2 = 'python          and           data              science'
str2.replace('        ', ' ')
# Out:
# 'python   and    data       science'

# %%
import re

# %%
str2 = '            python          and           data              science           '
re.sub(' +', ' ', str2).strip()
# Out:
# 'python and data science'

# %%
string = """Data science is an Interdisciplinary academic field[1] that Uses statistics, 
scientific computing, scientific methods, processing, Scientific visualIzation, 
algorithms and systems to Extract or Extrapolate knowledge from potentially noisy, 
structured, Or unstructured data."""

print(re.sub('[AEIOUaeiou]', '', string))
# Out:
# Dt scnc s n ntrdscplnry cdmc fld[1] tht ss sttstcs,
# scntfc cmptng, scntfc mthds, prcssng, Scntfc vslztn,
# lgrthms nd systms t xtrct r xtrplt knwldg frm ptntlly nsy,
# strctrd, r nstrctrd dt.

# %%
string = """Data science is an Interdisciplinary academic field[1] that Uses statistics, 


scientific computing, scientific methods, processing, Scientific visualIzation, 


algorithms and systems to Extract or Extrapolate knowledge from potentially noisy, 
structured, Or unstructured data."""

string.replace('\n',' ')
print(string.replace('\n',' '))
# Out:
# Data science is an Interdisciplinary academic field[1] that Uses statistics,    scientific computing, scientific methods, processing, Scientific visualIzation,    algorithms and systems to Extract or Extrapolate knowledge from potentially noisy,  structured, Or unstructured data.

# %%
string
# Out:
# 'Data science is an Interdisciplinary academic field[1] that Uses statistics, \n\n\nscientific computing, scientific methods, processing, Scientific visualIzation, \n\n\nalgorithms and systems to Extract or Extrapolate knowledge from potentially noisy, \nstructured, Or unstructured data.'

# %%
print(re.sub('\n+','\n', string))
# Out:
# Data science is an Interdisciplinary academic field[1] that Uses statistics,
# scientific computing, scientific methods, processing, Scientific visualIzation,
# algorithms and systems to Extract or Extrapolate knowledge from potentially noisy,
# structured, Or unstructured data.

# %%
str2 = 'python and data science'

str2.replace('a', 'A')
# Out:
# 'python And dAtA science'

# %%
str2 = 'python and data science'

str2.replace('a', 'A', count = 1)
# Out:
# 'python And data science'

# %%
str2 = 'python and data science'

str2.replace('a', 'A', count = 2)
# Out:
# 'python And dAta science'

# %%
str2 = 'python and data science python'

str2.replace('python', 'java', count = -1)
# Out:
# 'java and data science java'

# %%
str2 = 'python and data science python'

str2.replace('python', 'java', count = 1)
# Out:
# 'java and data science python'

# %% [markdown]
# ### 10. count

# %%
int_val = string.count('substring')

# %%
str2 = 'python and data science python'
str2.count('p')
# Out:
# 2

# %%
str2 = 'python and data science python'
str2.count('python')
# Out:
# 2

# %%
str2 = 'python and data science python'
str2.count('a')
# Out:
# 3

# %%
str2 = 'python and data science python'
str2.count('z')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.count(' ')
# Out:
# 4

# %%
str2 = 'python and data science python'
str2.count('PYTHON')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.upper().count('PYTHON')
# Out:
# 2

# %% [markdown]
# ### 11. index

# %%
substring_index = string.index('substring')

Raise error if substring is not present in string

# %%
str2 = 'python and data science python'
str2.index('python')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.index('and')
# Out:
# 7

# %%
str2 = 'python and data science python'
str2.index('a')
# Out:
# 7

# %%
str2 = 'python and data science python'
str2.index('Data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 str2 = 'python and data science python'
# ----> 2 str2.index('Data')
#
# ValueError: substring not found

# %% [markdown]
# ### 12. find

# %%
substring_index = string.index('substring')

Return -1 if substring is not present in string

# %%
str2 = 'python and data science python'
str2.find('Data')
# Out:
# -1

# %%
str2 = 'python and data science python'
str2.find('python')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.find('and')
# Out:
# 7

# %%
str2 = 'python and data science python'

if str2.find('Data') == -1:
    print('Substring not found')

else:
    print('Substring is Present')
# Out:
# Substring not found

# %%
str2 = 'python and data science python'

if str2.find('data') == -1:
    print('Substring not found')

else:
    print('Substring is Present')
# Out:
# Substring is Present

# %%
str2.find('data') == -1
# Out:
# False

# %%
str2.find('Data') == -1
# Out:
# True

# %% [markdown]
# ### 13. rindex

# %%
string.rindex()

# %%
str1 = 'deep learning'
str1.index('e')
# Out:
# 1

# %%
str1 = 'deep learning'
str1.rindex('e')
# Out:
# 6

# %%
str1 = 'deep learning'
str1.rindex('p')
# Out:
# 3

# %%
str2 = 'python and data science python'
str2.index('python')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.rindex('python')
# Out:
# 24

# %%
str2 = 'python and data science python'
str2.rindex('Data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 str2 = 'python and data science python'
# ----> 2 str2.rindex('Data')
#
# ValueError: substring not found

# %% [markdown]
# ### 14. rfind

# %%
str1.rfind()

# %%
str2 = 'python and data science python'
str2.rfind('Data')
# Out:
# -1

# %%
str2 = 'python and data science python'
str2.find('python')
# Out:
# 0

# %%
str2 = 'python and data science python'
str2.rfind('python')
# Out:
# 24

# %%
str2 = 'python and data science python'
str2.rfind('a')
# Out:
# 14

# %% [markdown]
# ### 15. split

# %%
string_list = string.split(substring)

default substring = ' '

list1 = [1,2,3,'Python']

# %%
str2 = 'python and data science python'
str2.split()
# Out:
# ['python', 'and', 'data', 'science', 'python']

# %%
str2 = 'python and data science python'
str2.split(" ")
# Out:
# ['python', 'and', 'data', 'science', 'python']

# %%
str2 = 'python     and data science python'
str2.split(" ")
# Out:
# ['python', '', '', '', '', 'and', 'data', 'science', 'python']

# %%
str2 = '''python and data science\npython'''
str2.split(" ")
# Out:
# ['python', 'and', 'data', 'science\npython']

# %%
text = '''Data science is a multidisciplinary field that combines mathematical,
statistical, and computational techniques to extract knowledge and insights from data'''
print(text.split())
# Out:
# ['Data', 'science', 'is', 'a', 'multidisciplinary', 'field', 'that', 'combines', 'mathematical,', 'statistical,', 'and', 'computational', 'techniques', 'to', 'extract', 'knowledge', 'and', 'insights', 'from', 'data']

# %%
text = '''Data science is a multidisciplinary field that combines mathematical,
statistical, and computational techniques to extract knowledge and insights from data'''
text_list = text.split()
len(text_list)
# Out:
# 20

# %%
text = '''Data science is a multidisciplinary field that combines mathematical,
statistical, and computational techniques to extract knowledge and insights from data'''
text_list = text.split('a')
print(text_list)
# Out:
# ['D', 't', ' science is ', ' multidisciplin', 'ry field th', 't combines m', 'them', 'tic', 'l,\nst', 'tistic', 'l, ', 'nd comput', 'tion', 'l techniques to extr', 'ct knowledge ', 'nd insights from d', 't', '']

# %%
text = '''Data science is a multidisciplinary field that combines mathematical,
statistical, and computational techniques to extract knowledge and insights from datA'''
text_list = text.split('a')
print(text_list)
# Out:
# ['D', 't', ' science is ', ' multidisciplin', 'ry field th', 't combines m', 'them', 'tic', 'l,\nst', 'tistic', 'l, ', 'nd comput', 'tion', 'l techniques to extr', 'ct knowledge ', 'nd insights from d', 'tA']

# %%
str1 = 'machine learning, deep learning and data science'
str1.split('learning')
# Out:
# ['machine ', ', deep ', ' and data science']

# %%
text = '''Data science is a multidisciplinary 
field that combines mathematical,
statistical, and computational techniques
to extract knowledge and insights from datA'''
text_list = text.split(' ')
print(text_list)
# Out:
# ['Data', 'science', 'is', 'a', 'multidisciplinary', '\nfield', 'that', 'combines', 'mathematical,\nstatistical,', 'and', 'computational', 'techniques\nto', 'extract', 'knowledge', 'and', 'insights', 'from', 'datA']

# %%
text = '''Data science is a multidisciplinary 
field that combines mathematical,
statistical, and computational techniques
to extract knowledge and insights from datA'''
text_list = text.split('\n')
print(len(text_list), text_list)
# Out:
# 4 ['Data science is a multidisciplinary ', 'field that combines mathematical,', 'statistical, and computational techniques', 'to extract knowledge and insights from datA']

# %%
str2 = 'data and deep learning and machine learning is a subset of AI and I love AI'
str2.split('and')
# Out:
# ['data ',
#  ' deep learning ',
#  ' machine learning is a subset of AI ',
#  ' I love AI']

# %%
print('Data','Science','ML', sep='         ')
# Out:
# Data         Science         ML

# %% [markdown]
# ### 16. join

# %%
'substring'.join(iterable)

iterable >> string, list, tuple

# %%
str1 = 'python'
' '.join(str1)
# Out:
# 'p y t h o n'

# %%
str1 = 'python'
'-'.join(str1)
# Out:
# 'p-y-t-h-o-n'

# %%
str1 = 'machine learning and data science'
list1 = str1.split()

list1   # ['machine', 'learning', 'and', 'data', 'science']

' '.join(list1)
# Out:
# 'machine learning and data science'

# %%
str1 = 'machine learning and data science'
list1 = str1.split()

list1   # ['machine', 'learning', 'and', 'data', 'science']

new_string = '--'.join(list1)
new_string
# Out:
# 'machine--learning--and--data--science'

# %%
tup1 = 'machine', 'learning', 'and', 'data', 'science'

new_string = '--'.join(tup1)
new_string
# Out:
# 'machine--learning--and--data--science'

# %%
type(tup1)
# Out:
# tuple

# %%
tup1 = ('machine', 'learning', 'and', 'data', 'science')

new_string = '--'.join(tup1)
new_string
# Out:
# 'machine--learning--and--data--science'

# %% [markdown]
# ### 17. endswith

# %%
string.endswith('substring')

It return result boolean dtype
True/False

True >> If Substring is present at the end of the string
False >> If Substring is not present at the end of the string

# %%
str1 = 'python'
str1.endswith('n')
# Out:
# True

# %%
str1 = 'python'
str1.endswith('x')
# Out:
# False

# %%
str1 = 'python'
str1.endswith(' ')
# Out:
# False

# %%
str1 = 'python and data science'
str1.endswith('e')
# Out:
# True

# %%
str1 = 'python and data science'
str1.endswith('science')
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### 18. startswith

# %%
string.startswith('substring')

It return result boolean dtype
True/False

True >> If Substring is present at the starts of the string
False >> If Substring is not present at the starts of the string

# %%
str1 = 'Mr. Ravindra Jadeja'
str1.startswith('Mr.')
# Out:
# True

# %%
str1 = 'Smt. Ravina Chattejee'
str1.startswith('Smt.')
# Out:
# True

# %%
str1 = 'Smt. Ravina Chattejee'
str1.startswith('Mr.')
# Out:
# False

# %% [markdown]
# ### 19. isalpha

# %%
string.isalpha()

True/False

If string contains only alphabets
alphabets >> a-z, A-Z

Space is not allowed

# %%
str1 = "Pune"
str1.isalpha()
# Out:
# True

# %%
str1 = "mumbai"
str1.isalpha()
# Out:
# True

# %%
str1 = "mumbai vs SRH"
str1.isalpha()
# Out:
# False

# %%
str1 = "mumbai1"
str1.isalpha()
# Out:
# False

# %%
str1 = "mum1bai"
str1.isalpha()
# Out:
# False

# %% [markdown]
# ### 20. isdecimal

# %%
string.isdecimal()

True >> If string contains only digits
digits >> 0-9

Space is not allowed

# %%
str1 = "mum1bai"
str1.isdecimal()
# Out:
# False

# %%
str1 = "9970881215"
str1.isdecimal()
# Out:
# True

# %%
str1 = "ABCDE1545P"
str1.isdecimal()
# Out:
# False

# %%
adhar_number = '4567 4864 1325'
adhar_number.isdecimal()
# Out:
# False

# %%
adhar_number = '4567 4864 1325'
adhar_number = adhar_number.replace(' ', '')

print('Adhaar Number :', adhar_number)

adhar_number.isdecimal()
# Out:
# Adhaar Number : 456748641325
# True

# %%
str1 = "12.45"
str1.isdecimal()
# Out:
# False

# %%
0 >> '\u0030'
1 >> '\u0031'
2 >> '\u0032'
...
9 >> '\u0039'

# %%
str('\u0030')
# Out:
# '0'

# %%
str('\u0045')
# Out:
# 'E'

# %%
num = '\u0030'
num.isdecimal()
# Out:
# True

# %%
num = '\u0045'
num.isdecimal()
# Out:
# False

# %%
num = '\u0045'
num.isalpha()
# Out:
# True

# %% [markdown]
# ### 21. isdigit

# %%
string.isdigit()

True >> If string contains only digits
digits >> 0-9

Space is not allowed

Unicodes of subscript and superscript

# %%
num = '12345'
num.isdecimal()
num.isdigit()
# Out:
# True

# %%
num = '12.345'
print(num.isdecimal())
num.isdigit()
# Out:
# False
# False

# %%
num = '12 345'
print(num.isdecimal())
num.isdigit()
# Out:
# False
# False

# %%
str('\u0035')
# Out:
# '5'

# %%
num = '\u0035'
print(num.isdecimal())
num.isdigit()
# Out:
# True
# True

# %%
str('\u2074')
# Out:
# '⁴'

# %%
str('\u2070')
# Out:
# '⁰'

# %%
str('\u2080')
# Out:
# '₀'

# %%
str('\u00B2')
# Out:
# '²'

# %%
num = '\u2070'
print(num.isdecimal())
num.isdigit()
# Out:
# False
# True

# %%
num = '\u00B2'
print(num.isdecimal())
num.isdigit()
# Out:
# False
# True

# %% [markdown]
# ### 22. isnumeric

# %%
string.isnumeric()

True >> If string contains only digits
digits >> 0-9

Space is not allowed

Unicodes of subscript and superscript
Unicodes of vulgar fraction

# %%
num = '4687'
print(num.isdecimal())
print(num.isdigit())
print(num.isnumeric())
# Out:
# True
# True
# True

# %%
num = '\u0035'
print(num.isdecimal())
print(num.isdigit())
print(num.isnumeric())
# Out:
# True
# True
# True

# %%
num = '\u00B2'
print(num.isdecimal())
print(num.isdigit())
print(num.isnumeric())
# Out:
# False
# True
# True

# %%
str('\u00BC')   # Vulgar fraction
# Out:
# '¼'

# %%
num = '\u00BC'      
print(num.isdecimal())
print(num.isdigit())
print(num.isnumeric())
# Out:
# False
# False
# True

# %% [markdown]
# ### 23. isalnum

# %%
string.isalnum

True >> if string contain only digits and alphabets

Space is not allowed

# %%
str1 = 'python'
str1.isalpha()
# Out:
# True

# %%
str1 = 'python'
str1.isalnum()
# Out:
# True

# %%
str1 = '46879'
str1.isalnum()
# Out:
# True

# %%
str1 = '46jmhgj879'
str1.isalnum()
# Out:
# True

# %%
str1 = 'python123'
str1.isalnum()
# Out:
# True

# %%
str1 = 'ABCDE1234G'
str1.isalnum()
# Out:
# True

# %%
str1 = 'ABCDE 1234G'
str1.isalnum()
# Out:
# False

# %% [markdown]
# ### 24. islower

# %%
str1.islower()

True >> If all alphabets are in lower case

space is allowed

# %%
str1 = 'Python'
str1.islower()
# Out:
# False

# %%
str1 = 'python'
str1.islower()
# Out:
# True

# %%
str1 = 'python and data science'
str1.islower()
# Out:
# True

# %%
str1 = 'python and data Science'
str1.islower()
# Out:
# False

# %%
str1 = 'python and data science 13435'
str1.islower()
# Out:
# True

# %%
str1 = '13435'
str1.islower()
# Out:
# False

# %%
str1 = 'a13435'
str1.islower()
# Out:
# True

# %% [markdown]
# ### 25. isupper

# %%
str1.isupper()

True >> If all alphabets are in upper case

space is allowed

# %%
str1 = 'DATA'
str1.isupper()
# Out:
# True

# %%
str1 = 'DATA 1354'
str1.isupper()
# Out:
# True

# %%
str1 = 'DATa 1354'
str1.isupper()
# Out:
# False

# %%
str1 = 'DATA @#$1354'
str1.isupper()
# Out:
# True

# %% [markdown]
# ### 26. istitle

# %%
str1.istitle()

True >> If all words are in title case

space is allowed

# %%
str1 = 'machine learning'
str1.istitle()
# Out:
# False

# %%
str1 = 'Machine Learning'
str1.istitle()
# Out:
# True

# %%
str1 = 'Machine Learning 684764#$%'
str1.istitle()
# Out:
# True

# %%
str1 = 'Machine Learning 684764#$% data'
str1.istitle()
# Out:
# False

# %%
str1 = 'Machine Learning 684764#$%data'
str1.istitle()
# Out:
# False

# %%
str1 = 'Machine Learning 684764#$%Data'
str1.istitle()
# Out:
# True

# %% [markdown]
# ### 27. isspace

# %%
str1.isspace()

True >> If string contain only spaces

# %%
str1 = '             '
str1.isspace()
# Out:
# True

# %%
str1 = '         .    '
str1.isspace()
# Out:
# False

# %%
str1 = '         1    '
str1.isspace()
# Out:
# False

# %%
str1 = ''
str1.isspace()
# Out:
# False

# %% [markdown]
# ### 28. zfill

# %%
str1.zfill(len of str)

# %%
str1 = 'Data'
str1.zfill(10)
# Out:
# '000000Data'

# %%
str1 = 'Data'
str1.zfill(15)
# Out:
# '00000000000Data'

# %% [markdown]
# ### 29. Center

# %%
str1.center(length, 'substring')

# %%
xx ---  xx

# %%
s1 = 'Machine Learning'
s1.center(30)
# Out:
# '       Machine Learning       '

# %%
s1 = 'Machine Learning'
s1.center(30, '*')
# Out:
# '*******Machine Learning*******'

# %%
s1 = ' Machine Learning '
s1.center(30, '*')
# Out:
# '****** Machine Learning ******'

# %%
s1 = ' Training Data Evaluation '
s1.center(50, '*')
# Out:
# '************ Training Data Evaluation ************'

# %%
s1 = ' Training Data Evaluation '
s1.center(50, '+')
# Out:
# '++++++++++++ Training Data Evaluation ++++++++++++'

# %%
3/4
# Out:
# 0.75

# %%
1 >> 4 (.25,.25,.25,.25) >> 3/4 >> .75
