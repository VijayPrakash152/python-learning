# %% [markdown]
# ### Boolean`

# %%
x = True
type(x)
# Out:
# bool

# %%
x = False
type(x)
# Out:
# bool

# %%
a = 1
b = 1
a == b
# Out:
# True

# %%
int(True)
# Out:
# 1

# %%
bool(1)
# Out:
# True

# %%
bool(19)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
list1 = [ ]
bool(list1)
# Out:
# False

# %%
list1 = [ 1]
bool(list1)
# Out:
# True

# %%
list1 = [1,2,3,4]

if bool(list1): # if True
    print('List is not Empty')

else:
    print('List is Empty')
# Out:
# List is not Empty

# %%
list1 = []

if bool(list1):  # if False
    print('List is not Empty')

else:
    print('List is Empty')
# Out:
# List is Empty

# %%
list1 = [1,2,3,4]

if list1: # bool(list1)
    print('List is not Empty')

else:
    print('List is Empty')
# Out:
# List is not Empty

# %%
list1 = []

if list1: # bool(list1)
    print('List is not Empty')

else:
    print('List is Empty')
# Out:
# List is Empty

# %%
list1 = []

if not list1: # bool(list1)
    print('List is Empty')

else:
    print('List is not Empty')
# Out:
# List is Empty

# %%
list1 = [1,2]

if not list1: # bool(list1)
    print('List is Empty')

else:
    print('List is not Empty')
# Out:
# List is not Empty
