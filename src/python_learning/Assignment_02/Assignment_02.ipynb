# %% [markdown]
# ## 1. What is a dictionary in Python? List out all properties of Dictionary.

# %% [markdown]
# A dictionary in Python is a mutable data structure that stores data as key-value pairs.
#
# A **dictionary** in Python is a mutable data structure that stores data as **key-value pairs**.
#
# ```python
# student = {
#     "name": "Vijay",
#     "age": 25,
#     "course": "Python"
# }
# ```
#
# ### Properties of a Dictionary
#
# 1. Stores data as **key-value pairs**.
# 2. Keys must be **unique**.
# 3. Keys must be **immutable and hashable** types, such as strings, numbers, or tuples.
# 4. Values can be of **any data type**.
# 5. Dictionaries are **mutable**, so items can be added, changed, or removed.
# 6. Dictionaries preserve **insertion order** in modern Python versions.
# 7. Dictionaries can contain **different data types**.
# 8. Dictionaries can be **nested** inside other dictionaries.
# 9. Values may be duplicated, but keys cannot.
# 10. Dictionaries are **dynamically sized**.
# 11. They support fast lookup using keys, typically with average $O(1)$ time complexity.
# 12. An empty dictionary is created using `{}` or `dict()`.
# 13. Accessing a missing key with `dictionary[key]` raises a `KeyError`; `.get()` can avoid this.
# 14. Dictionaries are iterable, and iteration normally proceeds over their keys.

# %% [markdown]
# ## 2. Explain the concept of dictionary comprehension in Python.

# %%
## Dictionary comprehension is a way to construct dictionary using a for loop in a single line.
my_list = [1,2,3,4,5]
my_dict = { elem: elem**2 for elem in my_list} ## elem becomes key and sqaure of elem becomes the value
print(my_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ## 3. Explain the difference between the dict.get(key) method and accessing dict[key] directly.

# %%
my_dict = {1:2, 2: 3, 3:4}

print(my_dict.get(5)) ## does not gives error if key is not present 
print(my_dict[5]) ## throws error if key is not present
# Out:
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 my_dict = {1:2, 2: 3, 3:4}
#       2
#       3 print(my_dict.get(5)) ## does not gives error if key is not present
# ----> 4 my_dict[5] ## throws error if key is not present
#
# KeyError: 5

# %% [markdown]
# ## 4. How can you merge two dictionaries in Python?

# %%
dict_1 = {"x": 1, "y":2, "z":3}
dict_2 = {"a": 1, "b":2, "c":3}

dict_3 = {**dict_1, **dict_2}

print(dict_3)

## another approach

dict_4 = dict_1 | dict_2
print(dict_4)
# Out:
# {'x': 1, 'y': 2, 'z': 3, 'a': 1, 'b': 2, 'c': 3}
# {'x': 1, 'y': 2, 'z': 3, 'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ## 5. How can you update dictionary values in Python? Provide examples.

# %%
my_dict = {"x": 1, "y":2, "z":3}

# my_dict.update({"x": 2}); one method , use it when we have to update mulitple key, values at one time.
my_dict["x"] = 2 # used when we have to update single value 
print(my_dict)
# Out:
# {'x': 2, 'y': 2, 'z': 3}

# %% [markdown]
# ## 6.How can you iterate over a dictionary to access keys, values, and key-value pairs?

# %%
my_dict = {"x": 1, "y":2, "z":3}

## printing keys
for key in my_dict:
    print(key)

## printing values
for value in my_dict.values():
    print(value)

## printing key,value pairs 
for key,value in my_dict.items():
    print(f"{key} : {value}")
# Out:
# x
# y
# z
# 1
# 2
# 3
# x : 1
# y : 2
# z : 3

# %% [markdown]
# ## 7. What are the different ways to delete items from dict

# %%
my_dict = {"x": 1, "y":2, "z":3}
del my_dict["x"] # raises key error if key does not exist
print(my_dict)
deleted_val = my_dict.pop("x", None) # deletes key and returns the value associated with it 
print(my_dict)
item = my_dict.popitem() # deletes abd returns the last inserted key,value pair 
print(my_dict)
my_dict.clear() # deletes all items but keeps the dictionary itself. 
print(my_dict)

## Deletes items based on a condition by creating a new dictionary.
my_dict = {"x": 1, "y":2, "z":3}
my_dict = {
    key: value
    for key, value in my_dict.items()
    if key != "y"
}

print(my_dict)
# Out:
# {'y': 2, 'z': 3}
# {'y': 2, 'z': 3}
# {'y': 2}
# {}
# {'x': 1, 'z': 3}

# %% [markdown]
# ## 8. Count the frequency of each word in a given sentence using a dictionary.

# %%
def count_words(sentence):
    words_dict = {}
    for word in sentence.split():
        words_dict[word] = words_dict.get(word, 0) + 1

    for key, value in words_dict.items():
        print(f"Word '{key}' is repeated {value} times. \n")


sentence = "the frog jumped over the ball"

count_words(sentence=sentence)
# Out:
# Word 'the' is repeated 2 times.
#
# Word 'frog' is repeated 1 times.
#
# Word 'jumped' is repeated 1 times.
#
# Word 'over' is repeated 1 times.
#
# Word 'ball' is repeated 1 times.

# %% [markdown]
# ## 9. Count the frequency of each character in a given word using a dictionary.

# %%
def count_letters(word):
    letters_dict = {}
    for letter in word:
        letters_dict[letter] = letters_dict.get(letter, 0) + 1

    for key, value in letters_dict.items():
        print(f"Letter '{key}' is repeated {value} times. \n")


word = "unforgettable"

count_letters(word=word)
# Out:
# Letter 'u' is repeated 1 times.
#
# Letter 'n' is repeated 1 times.
#
# Letter 'f' is repeated 1 times.
#
# Letter 'o' is repeated 1 times.
#
# Letter 'r' is repeated 1 times.
#
# Letter 'g' is repeated 1 times.
#
# Letter 'e' is repeated 2 times.
#
# Letter 't' is repeated 2 times.
#
# Letter 'a' is repeated 1 times.
#
# Letter 'b' is repeated 1 times.
#
# Letter 'l' is repeated 1 times.

# %% [markdown]
# ## 10. Sort a dictionary by keys and values.

# %%
my_dict = {"c": 3, "a": 1, "b": 2}

sorted_by_keys = dict(sorted(my_dict.items()))
print(sorted_by_keys)

sorted_by_values_in_asc_order = dict(sorted(my_dict.items(), key=lambda item: item[1]))
sorted_by_values_in_desc_order = dict(sorted(my_dict.items(), key=lambda item: item[1],reverse=True))
print(sorted_by_values_in_asc_order)
print(sorted_by_values_in_desc_order)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}
# {'c': 3, 'b': 2, 'a': 1}

# %% [markdown]
# ## 11. Find the sum of all values in a dictionary.

# %%
my_dict = {"a": 10, "b": 20, "c": 30}

sum_of_all_values = 0

for value in my_dict.values():
    sum_of_all_values += value

print(f"The sum of all values of the dictionary is {sum_of_all_values}")
# Out:
# The sum of all values of the dictionary is 60

# %% [markdown]
# ## 12. Create a dictionary using dictionary comprehension that
# ## contains even numbers as keys andtheir squares as values from 1 to 10.

# %%
my_dict = { elem:elem**2 for elem in [number for number in range(1,11) if number % 2 == 0 ] }
print(my_dict)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %% [markdown]
# ## 13. Group a list of words into lists of anagrams using a dictionary. Print the list of lists where each
# ## inner list contains words that are anagrams of each other.
# ## ● Input: ["listen", "silent", "enlist", "hello", "lemon", "melon", "debitcard", "badcredit"]
# ## ● Anagram groups: [['listen', 'silent', 'enlist'], ['hello'], ['lemon', 'melon'], ['debitcard','badcredit']]

# %%
input_list = ["listen", "silent", "enlist", "hello", "lemon", "melon", "debitcard", "badcredit"] 

def generate_hash(word):
    sorted_word = "".join(sorted(word))
    return sorted_word    


def group_anagrams(input_list):
    output_dict = {}

    for word in input_list:
        word_hash = generate_hash(word)
        output_dict.setdefault(word_hash,[]).append(word)

    output_list = [elem for elem in output_dict.values()]
    return output_list



print(group_anagrams(input_list=input_list))
# Out:
# [['listen', 'silent', 'enlist'], ['hello'], ['lemon', 'melon'], ['debitcard', 'badcredit']]

# %% [markdown]
# ## 14. Merge two dictionaries. If there are common keys, sum their values.
# ## Print the merged dictionary.

# %%
from collections import defaultdict

dict_1 = {"a": 10, "b": 20, "c": 30}
dict_2 = {"b": 5, "c": 15, "d": 40}

def merge_dictionary(dict_1,dict_2):
    merged_dictionary = defaultdict(int)

    for key,value in dict_1.items():
        merged_dictionary[key] += value

    for key,value in dict_2.items():
        merged_dictionary[key] += value

    return dict(merged_dictionary)

print(merge_dictionary(dict_1=dict_1,dict_2=dict_2))
# Out:
# {'a': 10, 'b': 25, 'c': 45, 'd': 40}

# %% [markdown]
# ## 15. Merge two lists into a dictionary using dictionary comprehension.

# %%
keys = ["name", "age", "course"]
values = ["Vijay", 25, "Python"]

# my_dict = { keys[i]: values[i] for i in range(len(keys))}

## more pythonic way 
my_dict = dict(zip(keys,values))

print(my_dict)
# Out:
# {'name': 'Vijay', 'age': 25, 'course': 'Python'}

# %% [markdown]
# ## 16. Find mirror characters in a string using a dictionary.
# ## For example, 'A' mirrors to 'Z', 'B' mirrors to 'Y',
# ## Input string: "Hello World"

# %%
# def find_mirror_chars(input_string):
# Out:
# Hello

# %% [markdown]
# ## 17. Convert a list of tuples into a dictionary.

# %%
my_tuples = [("x",2), ("y",3), ("z",4)]

my_dict = dict(my_tuples)

print(my_dict)
# Out:
# {'x': 2, 'y': 3, 'z': 4}

# %% [markdown]
# ## 18. Convert a dictionary to a list of tuples.

# %%
my_dict = {'x': 2, 'y': 3, 'z': 4}

print(list(my_dict.items()))
# Out:
# [('x', 2), ('y', 3), ('z', 4)]

# %% [markdown]
# ## 19. Create a dictionary that maps each lowercase and
# ## uppercase alphabet to its corresponding ASCII code.

# %%
import string

my_dict = {elem: ord(elem) for elem in string.ascii_letters}

print(my_dict)
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109, 'n': 110, 'o': 111, 'p': 112, 'q': 113, 'r': 114, 's': 115, 't': 116, 'u': 117, 'v': 118, 'w': 119, 'x': 120, 'y': 121, 'z': 122, 'A': 65, 'B': 66, 'C': 67, 'D': 68, 'E': 69, 'F': 70, 'G': 71, 'H': 72, 'I': 73, 'J': 74, 'K': 75, 'L': 76, 'M': 77, 'N': 78, 'O': 79, 'P': 80, 'Q': 81, 'R': 82, 'S': 83, 'T': 84, 'U': 85, 'V': 86, 'W': 87, 'X': 88, 'Y': 89, 'Z': 90}

# %% [markdown]
# ## 20. Count the number of vowels in a given string and store the counts in a dictionary.

# %%
vowel_dict = {}

def count_vowel_in_string(input_string):
    VOWELS = set('aeiouAEIOU')
    vowel_count = 0;
    for char in input_string:
        if char in VOWELS:
            vowel_count+=1

    vowel_dict[input_string] = vowel_count        

count_vowel_in_string("Hello")
count_vowel_in_string("World")

print(vowel_dict)
# Out:
# {'Hello': 2, 'World': 1}

# %% [markdown]
# ## 21. Create a nested dictionary where the keys are letters from 'A' to 'E' and the values are
# ## dictionaries mapping numbers from 1 to 5 to their squares.
# ## Output = { 'A': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, 'B': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25},...}

# %%
nested_dict = {char: {number: number**2 for number in range(1,6)}  for char in "ABCDE"}
print(nested_dict)
# Out:
# {'A': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, 'B': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, 'C': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, 'D': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, 'E': {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}}

# %% [markdown]
# ## 22. What is a set? List out all the properties of set.

# %% [markdown]
# A **set** in Python is an unordered, mutable collection of unique, hashable (immutable) elements. It is commonly created using curly braces `{}` or the `set()` function.
#
# ```python
# numbers = {1, 2, 3, 4, 5}
# ```
#
# ### Properties of a Set:
#
# 1. **Unordered**: Elements do not have a defined order, index, or position.
# 2. **Unique Elements**: Duplicate values are automatically removed.
# 3. **Mutable**: You can add (`.add()`) or remove (`.remove()`, `.discard()`) items from a set.
# 4. **Elements Must Be Hashable (Immutable)**: Items inside a set must be immutable (e.g., integers, floats, strings, tuples). Unhashable types like lists or dictionaries cannot be stored in a set.
# 5. **No Indexing or Slicing**: Since sets are unordered, indexing (`set[0]`) and slicing (`set[1:3]`) raise a `TypeError`.
# 6. **Heterogeneous**: Can store elements of different data types in the same set (e.g., `{1, "apple", (2, 3)}`).
# 7. **Fast Lookup ($O(1)$ Average Complexity)**: Checking for membership (`item in my_set`) is extremely fast because sets use a hash table internally.
# 8. **Supports Set Operations**: Provides built-in methods and operators for mathematical set operations:
#    - **Union** (`|` / `.union()`)
#    - **Intersection** (`&` / `.intersection()`)
#    - **Difference** (`-` / `.difference()`)
#    - **Symmetric Difference** (`^` / `.symmetric_difference()`)
# 9. **Empty Set Creation**: An empty set must be created using `set()`, because `{}` creates an empty dictionary.
# 10. **Iterable**: You can iterate over elements of a set using a `for` loop.

# %% [markdown]
# ## 23. Explain the difference between a set and a frozenset.

# %% [markdown]
# The main difference between a set and frozen set is that frozen set is immutable while set is mutable.

# %%
my_set = {1, 2, 3}
my_set.add(4)  # Works fine
print(my_set)  # {1, 2, 3, 4}
# Out:
# {1, 2, 3, 4}

# %%
my_frozen = frozenset([1, 2, 3])
# my_frozen.add(4)  # AttributeError: 'frozenset' object has no attribute 'add'

# %%
# frozenset as a dictionary key
dict_with_frozenset_key = {frozenset([1, 2]): "group_1"}

# set of sets (must use frozenset for inner sets)
set_of_sets = {frozenset([1, 2]), frozenset([3, 4])}

# %% [markdown]
# ## 24. Can you have a set of sets in Python? Explain with reasons.

# %% [markdown]
# No, you cannot have a set of standard set objects in Python.

# %%
set_of_sets = {{1,2},{3,4}} ## gives error because set elements must be hashable but sets are mutbale so there value can change with time, so set of sets is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 set_of_sets = {{1,2},{3,4}} ## gives error because set elements must be hashable but sets are mutbale so there value can change with time, so set of sets is not possible
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# ## 25. How are sets different from lists and tuples in Python?

# %% [markdown]
# Sets store unique values while list and tuples can have duplicates.
# Sets are unordered while list and tuples are ordered.
# Lookup time in Set is O(1) while in List and Tuples it is O(n)

# %% [markdown]
# ## 26. Find the minimum and maximum elements in a set without
# ## using the built-in min() and max() functions.
